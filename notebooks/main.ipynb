# %% [markdown]
# # ![Justiça do Trabalho](../assets/justice.svg) Justiça do Trabalho
#
# ## Dashboard dos dados da Justiça do Trabalho

# %%
import pandas as pd

# %% [markdown]
# ## 1. Extract - Load data

# %%
df = pd.read_csv(
    "../data/raw/Base de Dados JT Historico - CSV.csv",
    sep=";",
    encoding="latin-1",
    low_memory=False,
)
print(f"Total de linhas: {df.shape[0]}")
print(f"Total de colunas: {df.shape[1]}")
df.head()

# %%
df.info()
